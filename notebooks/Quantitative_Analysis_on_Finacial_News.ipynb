# %% [markdown]
# ### Technical Analysis on Finacial News
# Perform TA on News Data

# %%
# Enables automatic reloading of modules when they change and allows importing from the parent directory.
'''
Allow importing custom modules from the parent directory.
Ensure that any changes to those modules (e.g., editing a .py file in the parent directory) 
are automatically reloaded when you run cells, making development and testing more efficient.
'''

# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.append(os.path.abspath(".."))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Importing custom modules for technical analysis

from scripts.tenchnical_analysis import(load_stock_data, compute_indicators, plot_indicators,)

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (AAPL)

df = load_stock_data ("../data/AAPL_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="AAPL")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (AMZN)

df = load_stock_data ("../data/AMZN_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="AMZN")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (GOOG)

df = load_stock_data ("../data/GOOG_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="GOOG")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (META)

df = load_stock_data ("../data/META_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="META")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (MSFT)

df = load_stock_data ("../data/MSFT_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="MSFT")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (NVDA)

df = load_stock_data ("../data/NVDA_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="NVDA")

# %%
# Load stock data, compute indicators, and plot them
# for Apple Inc. (TSLA)

df = load_stock_data ("../data/TSLA_historical_data.csv")
df = compute_indicators(df)
plot_indicators(df, title="TSLA")
